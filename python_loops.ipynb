# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandrasekarThamizselvam/Practice_Python/blob/loops/python_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
start_num = int(input("Enter Starting Number: "))
end_num = int(input("Enter Ending Number: "))
print(f"{start_num}is the Starting Number and {end_num} is the Ending Number")
for(i) in range(start_num,end_num + 1):
    print(i)

# %%
for i in range(start_num,end_num + 1,3):
    print(i)

# %%
for i in range(end_num,start_num,-1):
    print(i)
